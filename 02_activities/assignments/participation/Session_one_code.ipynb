# %% [markdown]
# # Making a basic figure with matplotlib
# # Modified by Maria C. Tocora

# %%
# load libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy 
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50) # Random integers

fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x, y) # Scatter plot

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.barh(x,y) # Horizontal bars
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y) # Lines

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.hist(y) # Histogram
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
# Plot with labels
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y)

ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
# Out:
# Text(0.5, 0, 'Years since start')

# %%
# Font dictionaries
font1 = {'family':'sans-serif','color':'blue','size':20}

font2 = {'family':'monospace','color':'green',
         'size':14}

# %%
# Label with font dictionaries
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

ax.set_title('Total growth over time lets make this a really long title', fontdict = font1, loc='left')
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %% [markdown]
# # Modifying our data points
# # Modified by Maria C. Tocora

# %%
fig, ax = plt.subplots(figsize = (5,3))

ax.scatter(x, y,
           marker = '*', # Star shape
           color = 'indigo')

# %%
fig, ax = plt.subplots(figsize=(5,3))

ax.plot(x,y,
        marker = '*',
        color = '#7425b9',
        linestyle = '--',
        linewidth = 2)

# %%
fig, ax = plt.subplots(figsize=(5,3))

ax.plot(x,y,marker = '*',
        markersize = 12,
        color = '#7425b9',
        linestyle = '--',
        linewidth = 2,
        markeredgecolor = '#fa9359',
        markerfacecolor = '#000000')

ax.grid(axis = 'y', color='blue', # Color by name on the grid lines
        linewidth = 2, linestyle = '-.')

# %% [markdown]
# # My Chart inspired from https://python-graph-gallery.com/all-charts/
# ## More information available here https://github.com/matplotlib/cheatsheets

# %%
import seaborn as sns # Additional library

# %%
# Create a dataframe where the average value of the second column is higher than others:
df = pd.DataFrame(np.random.randn(10,10) * 4 + 3)
df[1]=df[1]+40
 
# If we do a heatmap, we just observe that one column has higher values than others:
sns.heatmap(df, cmap='viridis')
plt.show()

# Now if we normalize it by column:
df_norm_col=(df-df.mean())/df.std()
sns.heatmap(df_norm_col, cmap='viridis')
plt.show()
